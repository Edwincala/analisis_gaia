# %% [markdown]
# # Clasificación estelar según Gaia
#
# Por: Edwin Leonardo Cala Cardona

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Necesidad-del-estudio" data-toc-modified-id="Necesidad-del-estudio-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Necesidad del estudio</a></span></li><li><span><a href="#Hipótesis-del-estudio" data-toc-modified-id="Hipótesis-del-estudio-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Hipótesis del estudio</a></span></li><li><span><a href="#Base-de-datos" data-toc-modified-id="Base-de-datos-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Base de datos</a></span></li><li><span><a href="#Problema" data-toc-modified-id="Problema-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Problema</a></span></li><li><span><a href="#Marco-Teórico" data-toc-modified-id="Marco-Teórico-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Marco Teórico</a></span><ul class="toc-item"><li><span><a href="#Gaia:" data-toc-modified-id="Gaia:-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Gaia:</a></span><ul class="toc-item"><li><span><a href="#¿Qué-contienen-los-Data-releases?" data-toc-modified-id="¿Qué-contienen-los-Data-releases?-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>¿Qué contienen los Data releases?</a></span></li><li><span><a href="#Caracterización-de-las-estrellas:" data-toc-modified-id="Caracterización-de-las-estrellas:-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Caracterización de las estrellas:</a></span></li></ul></li><li><span><a href="#Clasificación-de-las-estrellas:" data-toc-modified-id="Clasificación-de-las-estrellas:-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Clasificación de las estrellas:</a></span></li></ul></li><li><span><a href="#Análisis-exploratorio-de-los-datos-y-preparación" data-toc-modified-id="Análisis-exploratorio-de-los-datos-y-preparación-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Análisis exploratorio de los datos y preparación</a></span><ul class="toc-item"><li><span><a href="#Preparación-y-limpieza-de-los-datos" data-toc-modified-id="Preparación-y-limpieza-de-los-datos-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Preparación y limpieza de los datos</a></span></li></ul></li><li><span><a href="#Análisis-de-datos:" data-toc-modified-id="Análisis-de-datos:-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Análisis de datos:</a></span><ul class="toc-item"><li><span><a href="#Generación-del-modelo-de-clasificación-de-estrellas." data-toc-modified-id="Generación-del-modelo-de-clasificación-de-estrellas.-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Generación del modelo de clasificación de estrellas.</a></span><ul class="toc-item"><li><span><a href="#Separación-del-dataset-para-entrenamiento-y-testeo" data-toc-modified-id="Separación-del-dataset-para-entrenamiento-y-testeo-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Separación del dataset para entrenamiento y testeo</a></span></li><li><span><a href="#Implementación-modelo-de-clasificación" data-toc-modified-id="Implementación-modelo-de-clasificación-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>Implementación modelo de clasificación</a></span></li><li><span><a href="#Predicción-de-estrellas-nuevas:" data-toc-modified-id="Predicción-de-estrellas-nuevas:-7.1.3"><span class="toc-item-num">7.1.3&nbsp;&nbsp;</span>Predicción de estrellas nuevas:</a></span></li></ul></li><li><span><a href="#Evaluación-del-modelo" data-toc-modified-id="Evaluación-del-modelo-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Evaluación del modelo</a></span></li></ul></li><li><span><a href="#Resultados-y-discusión" data-toc-modified-id="Resultados-y-discusión-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Resultados y discusión</a></span></li><li><span><a href="#Conclusiones" data-toc-modified-id="Conclusiones-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Conclusiones</a></span></li><li><span><a href="#Referencias" data-toc-modified-id="Referencias-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Referencias</a></span></li></ul></div>

# %% [markdown]
# # Contexto de Investigación
#
# Por medio del desarrollo de este proyecto, se podrá desarrollar un algoritmo de clasificación que determine el tipo de una estrella con distintas propiedades en 7 posibles clases.
#
# ## Necesidad del estudio
#
# Gaia es una sonda espacial que explora y realiza un mapeo tridimensional de la vía láctea y más allá, y sigue recopilando cada vez más información sobre las estrellas. Gaia es solo uno de los tantos artefactos en el espacio obteniendo datos e información nueva por el bien de la ciencia y la exploración espacial. Por medio de este estudio se podrá generar un algoritmo que permita clasificar una estrella nueva con ciertas propiedades en 7 posibles clases. Al encontrar la clase de estrella, se puede estudiar su entorno para responder a interrogantes propios del ser humano, como el saber si existe vida extraterrestre, o predecir fenómenos como los agujeros negros debidos a la explosión de estrellas y su posible influencia en la Tierra y el Sistema Solar.
#
# ## Hipótesis del estudio
#
# Al revisar el conjunto de datos, se pueden encontrar distintas caraterísticas de las estrellas registradas por Gaia, entre ellas datos como la temperatura efectiva estimada por Gaia, el radio en relación con el Sol, algunos índices de color y la luminosidad de las estrellas. Estas características podrían ser las que más afectan en la clasificación de las estrellas, que durante el desarrollo del análisis de correlación de las variables, se podrá establecer si esto es correcto, o si existen más variables que no se consideraron inicialmente, pero que afectarían en dicha clasificación.

# %% [markdown]
# ## Base de datos
# <section id="database"></section>
# Se posee una base de datos de Gaia <a href="https://www.kaggle.com/datasets/realkiller69/gaia-data-set-for-stellar-classificationdr3?resource=download">[1]</a> (DR3) (ESA) para la clasificación de estrellas, se tienen en cuenta los siguientes parámetros:
# * RA_ICRS: Right ascension in the ICRS (International Celestial Reference System) coordinate system.
#     (ESP: Ascensión recta en el sistema de coordenadas ICRS (Sistema Internacional de Referencia Celestial)).
#
# * DE_ICRS: Declination in the ICRS coordinate system. (ESP: Declinación en el sistema de coordenadas ICRS.)
# * Source: Unique identifier for an object in the Gaia catalogue. (ESP: Identificador único para un objeto en el catálogo Gaia)
# * Plx: Trigonometric parallax of the celestial body in milliarcseconds. (ESP: Parallax trigonométrico del cuerpo celeste en miliarcsegundos.)
# * PM: Total proper motion of the celestial body in the sky in milliarcseconds per year. (ESP: Movimiento propio total del cuerpo celeste en el cielo en milisegundos de arco por año.)
# * pmRA: Proper motion component in the right ascension direction in milliarcseconds per year. (ESP: Componente del movimiento propio en la dirección de ascensión recta en milisegundos de arco por año.)
# * pmDE: Proper motion component in the declination direction in milliarcseconds per year. (ESP: Componente del movimiento propio en la dirección de declinación en milisegundos de arco por año.)
# * Gmag: Average apparent magnitude integrated in the G band. (ESP: Magnitud aparente media integrada en la banda G.)
# * e_Gmag: Error in G magnitude. (ESP: Error en magnitud G.)
# * BPmag: Average apparent magnitude integrated in the BP blue band. (ESP: Magnitud aparente promedio integrada en la banda azul de BP.)
# * e_BPmag: Error associated with BP magnitude. (ESP: Error asociado con la magnitud de la PA.)
# * RPmag: Average apparent magnitude integrated in the RP red band. (ESP: Magnitud aparente promedio integrada en la banda roja del RP.)
# * e_RPmag: Error in RP magnitude. (ESP: Error en la magnitud RP.)
# * GRVSmag: Average apparent magnitude integrated in the RVS band. (ESP: Magnitud aparente media integrada en la banda RVS.)
# * e_GRVSmag: Error in RVS magnitude. (ESP: Error en la magnitud RVS.)
# * BP-RP: BP-RP color index. (ESP: Índice de color BP-RP.)
# * BP-G: BP-G color index. (ESP: Índice de color BP-G.)
# * G-RP: G-RP color index. (ESP: Índice de color G-RP.)
# * pscol: pseudocolor estimated by gaia in um<sup>-1</sup> (ESP: Pseudocolor estimado por Gaia en um<sup>-1</sup>)
# * Teff: Estimated effective temperature of the celestial object by Gaia in Kelvins. (ESP: Temperatura efectiva estimada del objeto celeste por Gaia en Kelvins.)
# * Dist: Distance to the celestial object: inverse of the parallax, in parsecs. (ESP: Distancia al objeto celeste: inversa del parallax, en pársecs.)
# * Rad: Object radius estimate in terms of solar radius. (ESP: Estimación del radio del objeto en términos de radio solar.)
# * Lum-Flame: Estimated object luminosity in terms of solar luminosity. (ESP: Luminosidad estimada del objeto en términos de luminosidad solar.)
# * Mass-Flame: Mass estimate in terms of solar mass. (ESP: Estimación de masa en términos de masa solar.)
# * Age-Flame: Celestial object age in giga years. (ESP: Edad de los objetos celestes en giga años. $1\text{ giga año} = 10^9\text{ años}$)
# * z-Flame: Redshift in km/s. (ESP: Corrimiento al rojo en km/s.)
# * SpType-ELS: Estimated spectral class by Gaia. (ESP: Clase espectral estimada por Gaia.)
#
# Fuente: [kaggle datasets](https://www.kaggle.com/datasets/realkiller69/gaia-data-set-for-stellar-classificationdr3?resource=download)

# %% [markdown]
# ## Problema
#
# A partir del uso de regresiones lineales con Python, y algoritmos de Machine learning, será posible clasificar una estrella de acuerdo a algunos parámetros propios de la misma en 7 posibles clases: A, B, F, G, K, M, O, por medio de una regresión logística, de manera que el algoritmo al recibir datos de entrada sobre una estrella, prediga su clasificación.

# %% [markdown]
# ## Marco Teórico
#
# ### Gaia:
# <section id="gaia"></section>
# Sonda espacial lanzada el 19 de Diciembre de 2013 desde la Guayana Francesa. Su función es la de crear un mapa tridimensional de la Vía Lactea, que contenga la posición, la velocidad, la dirección de movimiento, brillo, temperatura y composición de casi 2 billones de objetos en nuestra galaxia y más allá. Esta información le permitiría a los astrónomos reconstruir su pasado y evolución a futuro en billones de años.

# %%
# %%html
# <h3>Más información sobre <a href="https://www.youtube.com/embed/Ku8EGR6N1MM?si=vBAoS0hEZgsP1qFy">Gaia [2]</a></h3><br/>
# <iframe width="560" height="315" src="https://www.youtube.com/embed/Ku8EGR6N1MM?si=vBAoS0hEZgsP1qFy" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
# Out:
# <h3>Más información sobre <a href="https://www.youtube.com/embed/Ku8EGR6N1MM?si=vBAoS0hEZgsP1qFy">Gaia</a></h3><br/>
# <iframe width="560" height="315" src="https://www.youtube.com/embed/Ku8EGR6N1MM?si=vBAoS0hEZgsP1qFy" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %% [markdown]
# <section id="dr3"></section>
# Gaia ha generado 4 datasets hasta la fecha[3]:
#
# * Data Release 1 (DR1): 14 Septiembre 2016
# * Data Release 2 (DR2): 25 Abril 2018
# * Early Data Release 3 (EDR3): 3 Diciembre 2020
# * Data Release 3 (DR3): 13 Junio 2022
#
# Se tiene proyectado un quinto release de datos el 10 de Octubre de 2023.
#
# #### ¿Qué contienen los Data releases?
#
# De acuerdo a la información provista por ESA <a href="https://esamultimedia.esa.int/docs/science/Gaia_DR3_mediakit_final_English.pdf">[3]</a>, el Data Release 3, bajo el cual se desarollará este artículo, contiene información de:
#
# * El mayor estudio de espectroscopía de baja resolución jamás realizado.
# * El estudio de velocidad radial más grande jamás realizado.
# * La mayor recopilación de datos astrofísicos de estrellas de la Vía Láctea hasta la fecha.
# * Para muchas clases de estrellas variables: el estudio más grande jamás realizado.
# * Estudio de estrellas binarias que supera todos los trabajos sobre estrellas binarias de los últimos dos siglos.
# * Estudio de mayor precisión de asteroides combinando sus composiciones con sus orbitas.
# * Primer estudio espacial de todo el cielo sobre los quásares y su forma de galaxias en el Universo local.
# * Estudio fotométrico de la galaxia de Andrómeda.
#
# #### Caracterización de las estrellas:
#
# La metodología que usa ESA por medio de Gaia para el análisis de las estrellas vecinas comprende principalmente tres técnicas [3]:
#
# 1. <strong>Astrometría:</strong> Medición de distancia, posición y movimiento propio de la estrella.
# 2. <strong>Fotometría:</strong> Observación de la edad, luminosidad, cambios en la luminosidad, temperatura, masa, color, polvo y metalicidad.
# 3. <strong>Espectrocopia:</strong> Determinación de la composición química, velocidad radial y de rotación por medio de los espectros de luz.
#
# ### Clasificación de las estrellas:
# <section id="clasificacion"></section>
# Según Astrobitácora.com <a href="https://www.astrobitacora.com/la-clasificacion-estelar/">[4]</a>, existen tres factores principales para la clasificación de las estrellas, la clase espectral, el color y magnitud absoluta. La clase espectral es una especie de código que resume el estado de ionización de la estrella, y permite calcular la temperatura de la fotósfera y su densidad.
#
# Existen 7 clases de estrellas definidas en el catálogo de Gaia: O, B, A, F, G, K y M.
#
# * <strong>Clase O:</strong> Estas estrellas poseen una temperatura de entre 30000 y 60000 K, emiten un color azul. Debido a las altas temperaturas e intensidades de luminosidad, suelen poseer una vida corta, explotando de manera violenta, dando lugar a agujeros negros y estrellas de neutrones.
#
# * <strong>Clase B:</strong> Poseen una temperatura de entre 10000 y 30000 K, la luz que emiten es de color azul también, suelen tener una masa de entre 2 y 16 veces la del Sol. No poseen corona (aura de plasma) ni zona de convección (zona en la que la energía es transmitida por convección).
#
# * <strong>Clase A:</strong> Tienen una temperatura de entre 7500 y 10000 K. La luz que emiten es de color blanco, poseen una masa de entre 1.4 y 2.1 veces la del Sol. Se indica que los planetas masivos son formados alrededor de estrellas de este tipo.
#
# * <strong>Clase F:</strong> La temperatura de estas estrellas oscila entre los 6000 y 7500 K, emiten un color blanco ligeramente amarillento, su masa es de entre 1 y 1.4 veces la masa del sol. Son consideradas estrellas enanas.
#
# * <strong>Clase G:</strong> Su temperatura es de entre 5000 y 6000 K, tienen una masa de entre 0.8 y 1.2 veces la del Sol. Emiten luz de color blanco, el Sol pertenece a este grupo, y aunque aparentemente la luz es de color amarillo, esto se debe a un fenómeno llamado la dispersión de Rayleigh. Su periodo de vida es de aproximadamente unos 10000 millones de años.
#
# * <strong>Clase K:</strong> El rango de temperaturas es de entre 3500 y 5000 K, emiten luz de color anaranjado. Su masa es de entre 0.6 y 0.9 masas solares, poseen un periodo de vida de entre 15000 y 30000 millones de años. Debido a su baja transmisión de rayos ultravioleta, estas estrellas son objetivos para los astrónomos para buscar planetas con vida extraterrestre.
#
# * <strong>Clase M: </strong> Estas estrellas poseen temperaturas de entre 2000 y 3500 K, son de un color rojizo, su etapa principal de evolución es del orden de billones de años, por lo que son bastante longevas a comparación de los otros tipos de estrellas.

# %% [markdown]
# ## Análisis exploratorio de los datos y preparación

# %% [markdown]
# ### Preparación y limpieza de los datos

# %% [markdown]
# La base de datos usada contiene 28 columnas y 611689 filas, y la variable de interés es una de tipo categórico, que corresponde con el nombre "SpType-ELS" que contiene a los posibles tipos de estrellas existentes en el catálogo de Gaia.

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/dataGaia.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'RA_ICRS', 'DE_ICRS', 'Source', 'Plx', 'PM', 'pmRA',
#        'pmDE', 'Gmag', 'e_Gmag', 'BPmag', 'e_BPmag', 'RPmag', 'e_RPmag',
#        'GRVSmag', 'e_GRVSmag', 'BP-RP', 'BP-G', 'G-RP', 'pscol', 'Teff',
#        'Dist', 'Rad', 'Lum-Flame', 'Mass-Flame', 'Age-Flame', 'z-Flame',
#        'SpType-ELS'],
#       dtype='object')

# %%
print(df.shape)
df.head(10)
# Out:
# (611689, 25)
#      RA_ICRS   DE_ICRS      Plx      PM    pmRA    pmDE       Gmag    e_Gmag  \
# 0  47.451110  2.205457   1.1750   8.488   2.263  -8.181  10.966603  0.002786
# 1  44.375187  2.895901   1.8937  16.954   7.031 -15.427  10.369156  0.002801
# 2  42.959304  2.920459   2.9732   2.528   1.795   1.780  10.038978  0.002774
# 3  44.031079  3.203683   2.2337  10.776  -3.151 -10.305   9.810181  0.002786
# 4  45.463599  3.138095   4.0179  10.053   1.828   9.885   8.163041  0.002800
# 5  43.784164  3.486814  11.6458  32.355  29.688 -12.863   6.855547  0.002779
# 6  47.761310  2.904850   1.9305   8.954   6.145  -6.512  11.135796  0.002781
# 7  49.046211  3.700545   1.8239  10.539  -5.489  -8.996  11.412380  0.002806
# 8  48.237358  4.055506   1.7571   5.235  -4.549  -2.590  10.735039  0.002767
# 9  48.732073  4.300161   5.7774   6.192   3.129  -5.343   8.814120  0.002829
#
#        BPmag   e_BPmag  ...      BP-G      G-RP    Teff      Dist     Rad  \
# ...

# %%
df.groupby('SpType-ELS').apply(list)
# Out:
# SpType-ELS
# A          [Unnamed: 0, RA_ICRS, DE_ICRS, Source, Plx, PM...
# B          [Unnamed: 0, RA_ICRS, DE_ICRS, Source, Plx, PM...
# F          [Unnamed: 0, RA_ICRS, DE_ICRS, Source, Plx, PM...
# G          [Unnamed: 0, RA_ICRS, DE_ICRS, Source, Plx, PM...
# K          [Unnamed: 0, RA_ICRS, DE_ICRS, Source, Plx, PM...
# M          [Unnamed: 0, RA_ICRS, DE_ICRS, Source, Plx, PM...
# O          [Unnamed: 0, RA_ICRS, DE_ICRS, Source, Plx, PM...
# dtype: object

# %% [markdown]
# Se eliminan las columnas "Unnamed: 0" y "Source", ya que no proveen información para el análisis, puesto que la primera corresponde con una enumeración proporcionada por Gaia a cada uno de los registros, de una forma incoherente, y la segunda es el identificador que posee Gaia para catalogar cada objeto, por lo que se disminuye el número de columnas a 26.

# %%
df = df.drop(['Unnamed: 0'], axis=1)
df = df.drop(['Source'], axis=1)

# %%
print("Dataframe shape:", df.shape)
df.head(5)
# Out:
# Dataframe shape: (611689, 26)
#      RA_ICRS   DE_ICRS     Plx      PM   pmRA    pmDE       Gmag    e_Gmag  \
# 0  47.451110  2.205457  1.1750   8.488  2.263  -8.181  10.966603  0.002786
# 1  44.375187  2.895901  1.8937  16.954  7.031 -15.427  10.369156  0.002801
# 2  42.959304  2.920459  2.9732   2.528  1.795   1.780  10.038978  0.002774
# 3  44.031079  3.203683  2.2337  10.776 -3.151 -10.305   9.810181  0.002786
# 4  45.463599  3.138095  4.0179  10.053  1.828   9.885   8.163041  0.002800
#
#        BPmag   e_BPmag  ...      G-RP   pscol    Teff      Dist     Rad  \
# 0  11.007946  0.002966  ...  0.090974     NaN  9406.7  918.2012  2.3686
# 1  10.441856  0.003698  ...  0.163792     NaN  9348.7  679.7121  2.4642
# 2  10.212755  0.002847  ...  0.304139     NaN  7520.7  339.8108  1.9321
# 3  10.008457  0.002864  ...  0.338961  1.5956  7052.3  433.9715  2.9735
# 4   8.197672  0.003043  ...  0.091842     NaN  9982.8  251.2483  2.2829
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
df['SpType-ELS'].value_counts()
# Out:
# SpType-ELS
# A          100000
# F          100000
# G          100000
# K          100000
# M          100000
# B           85673
# O           26016
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611689 entries, 0 to 611688
# Data columns (total 26 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   RA_ICRS     611689 non-null  float64
#  1   DE_ICRS     611689 non-null  float64
#  2   Plx         611689 non-null  float64
#  3   PM          611689 non-null  float64
#  4   pmRA        611689 non-null  float64
#  5   pmDE        611689 non-null  float64
#  6   Gmag        611688 non-null  float64
#  7   e_Gmag      611688 non-null  float64
#  8   BPmag       611688 non-null  float64
#  9   e_BPmag     611688 non-null  float64
#  10  RPmag       611689 non-null  float64
#  11  e_RPmag     611689 non-null  float64
#  12  GRVSmag     507721 non-null  float64
#  13  e_GRVSmag   507721 non-null  float64
#  14  BP-RP       611688 non-null  float64
#  15  BP-G        611688 non-null  float64
#  16  G-RP        611688 non-null  float64
#  17  pscol       16388 non-null   float64
# ...

# %% [markdown]
# A partir de este conteo, es posibles establecer que las estrellas de tipo O y B no son tan frecuentes en la vía láctea según el mapeo realizado por Gaia a diferencia de los 5 demás tipos.

# %%
print(f"Porcentaje de estrellas tipo B: {round(df['SpType-ELS'].value_counts()[1]/df.shape[0]*100, 5)} %")
print(f"Porcentaje de estrellas tipo O: {round(df['SpType-ELS'].value_counts()[6]/df.shape[0]*100, 5)} %")
# Out:
# Porcentaje de estrellas tipo B: 14.00597 %
# Porcentaje de estrellas tipo O: 4.25314 %

# %%
pd.DataFrame({"Datos faltantes":df.isna().sum(), "Porcentajes datos faltantes": df.isna().sum()*100/df.shape[0]})
# Out:
#             Datos faltantes  Porcentajes datos faltantes
# RA_ICRS                   0                     0.000000
# DE_ICRS                   0                     0.000000
# Plx                       0                     0.000000
# PM                        0                     0.000000
# pmRA                      0                     0.000000
# pmDE                      0                     0.000000
# Gmag                      1                     0.000163
# e_Gmag                    1                     0.000163
# BPmag                     1                     0.000163
# e_BPmag                   1                     0.000163
# RPmag                     0                     0.000000
# e_RPmag                   0                     0.000000
# GRVSmag              103968                    16.996873
# e_GRVSmag            103968                    16.996873
# BP-RP                     1                     0.000163
# ...

# %% [markdown]
# <section id="missingness"></section>
# A partir de la tabla anterior, que contiene los valores faltantes por columna, y el porcentaje que representa con respecto al total de los datos es posible establecer que el parámetro "pscol" tiene un 97.32086% de valores faltantes, de manera que se elimina dicha columna del conjunto de datos. El resto de parámetros posee una pérdida relativamente baja, con porcentajes inferiores al <a href="https://discuss.analyticsvidhya.com/t/what-should-be-the-allowed-percentage-of-missing-values/2456/9">25%-30% [5]</a>, por lo que nos será posible imputar los datos o eliminar los registros vacíos.

# %%
df = df.drop(['pscol'], axis=1)

# %%
import seaborn as sns
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %% [markdown]
# Al avanzar en el análisis de datos, fue posible establecer que la eliminación de filas no es viable puesto que los valores faltantes en su mayoría corresponden con las estrellas de tipo O, puesto al contar las posibles salidas, se pierde esa clase, de manera que se procedió a realizar el análisis con los datos que se poseen ya. El siguiente paso es convertir la columna de tipo categórica en una de tipo numérica, esto por medio del módulo LabelEncoder de la librería sklearn.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df['SpType-ELS'].unique()
# Out:
# array(['A      ', 'B      ', 'F      ', 'G      ', 'K      ', 'M      ',
#        'O      '], dtype=object)

# %%
encoder = LabelEncoder()
df['SpType-ELS'] = encoder.fit_transform(df['SpType-ELS'])
df.head(5)
# Out:
#      RA_ICRS   DE_ICRS     Plx      PM   pmRA    pmDE       Gmag    e_Gmag  \
# 0  47.451110  2.205457  1.1750   8.488  2.263  -8.181  10.966603  0.002786
# 1  44.375187  2.895901  1.8937  16.954  7.031 -15.427  10.369156  0.002801
# 2  42.959304  2.920459  2.9732   2.528  1.795   1.780  10.038978  0.002774
# 3  44.031079  3.203683  2.2337  10.776 -3.151 -10.305   9.810181  0.002786
# 4  45.463599  3.138095  4.0179  10.053  1.828   9.885   8.163041  0.002800
#
#        BPmag   e_BPmag  ...      BP-G      G-RP    Teff      Dist     Rad  \
# 0  11.007946  0.002966  ...  0.041343  0.090974  9406.7  918.2012  2.3686
# 1  10.441856  0.003698  ...  0.072701  0.163792  9348.7  679.7121  2.4642
# 2  10.212755  0.002847  ...  0.173778  0.304139  7520.7  339.8108  1.9321
# 3  10.008457  0.002864  ...  0.198277  0.338961  7052.3  433.9715  2.9735
# 4   8.197672  0.003043  ...  0.034631  0.091842  9982.8  251.2483  2.2829
#
#    Lum-Flame  Mass-Flame  Age-Flame   z-Flame  SpType-ELS
# ...

# %% [markdown]
# Por medio de la siguiente tabla, se podrán observar los rangos de valores que posee cada columna,los cuartiles, la desviación estándar y la media.

# %%
df.describe()
# Out:
#              RA_ICRS        DE_ICRS            Plx             PM  \
# count  611689.000000  611689.000000  611689.000000  611689.000000
# mean      109.491138      27.375246       1.490339      11.264492
# std        99.486049      26.856553       2.030546      19.482668
# min         0.000205     -89.098460      -5.014100       0.002000
# 25%        46.677751      18.623979       0.320800       2.450000
# 50%        67.259343      31.172183       0.872600       5.591000
# 75%       110.040669      43.118327       1.659900      11.078000
# max       359.997541      89.774031      95.047700     688.189000
#
#                 pmRA           pmDE           Gmag         e_Gmag  \
# count  611689.000000  611689.000000  611688.000000  611688.000000
# mean        1.416328      -5.646765      13.720603       0.002857
# std        16.120819      14.583911       1.690560       0.000569
# min      -584.663000    -583.413000       2.740842       0.002757
# ...

# %% [markdown]
# Por medio de la matriz de correlación mostrada a continuación, se observa la proporcionalidad de un parámetro con respecto a otro. Lo que se busca encontrar por medio de esta matriz es definir las variables que al aumentar o disminuír sus valores, cambien la clasificación de estrellas, por lo que se encontrarán los parámetros los cuales al aplicarse el valor absoluto de su correlación sean cercanos a 1, que visto en la matriz convertida en un mapa de calor serán aquellos parámetros que posean un color claro (tonalidades cercanas al color blanco) u oscuro (tonalidades cercanas al color negro).

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)
# Out:
# <Axes: >

# %%
corr
# Out:
#              RA_ICRS   DE_ICRS       Plx        PM      pmRA      pmDE  \
# RA_ICRS     1.000000 -0.206670  0.030683  0.055337 -0.109554  0.012326
# DE_ICRS    -0.206670  1.000000  0.019752 -0.047041  0.012013  0.044044
# Plx         0.030683  0.019752  1.000000  0.745478  0.107380 -0.379830
# PM          0.055337 -0.047041  0.745478  1.000000  0.181589 -0.568065
# pmRA       -0.109554  0.012013  0.107380  0.181589  1.000000 -0.085398
# pmDE        0.012326  0.044044 -0.379830 -0.568065 -0.085398  1.000000
# Gmag       -0.028364 -0.110992 -0.237956 -0.073438 -0.060166  0.050771
# e_Gmag      0.105507 -0.098454 -0.047551 -0.024059 -0.017727  0.012764
# BPmag       0.071702 -0.139995 -0.201409 -0.035736 -0.066939  0.027563
# e_BPmag     0.236813 -0.189471 -0.104919 -0.047191 -0.043991  0.022541
# RPmag      -0.073638 -0.095786 -0.268933 -0.108831 -0.058308  0.072044
# e_RPmag     0.109110 -0.221587 -0.101247 -0.057679 -0.025759  0.034452
# ...

# %%
import numpy as np
import matplotlib.colors as colors
import matplotlib.cm as cmx

threshold = 0.5

# %% [markdown]
# Se agregó un valor de filtrado de 0.5, para determinar cuales eran las variables con mayor correlación ya sea positiva o negativa, y se agregaron a un array, del cual, se pudo obtener que las variables son las contenidas en la lista "greatest_corr_cols".

# %%
np.abs(corr.values) > threshold
# Out:
# array([[ True, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False,  True, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False,  True,  True, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False,  True,  True, False,  True, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False,  True, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
# ...

# %%
g_c_vars_no_rep = []
temp = set()
greatest_corr_vars = [(i, j) for i,j in zip(*np.where(np.abs(corr.values) > threshold)) if i!=j]
g_c_vars_no_rep = [temp.add((a, b)) for (a, b) in greatest_corr_vars if (a, b) and (b, a) not in temp]
g_c_vars_no_rep = list(temp)
g_c_vars_no_rep.append((17, 24))
g_c_vars_no_rep.append((19, 24))

print(df.shape)
sptype_corr_vars = [x for x in g_c_vars_no_rep if (df.shape[1] - 1) in x]

print(greatest_corr_vars)
print(g_c_vars_no_rep)
print(sptype_corr_vars)
# Out:
# (611689, 25)
# [(2, 3), (3, 2), (3, 5), (5, 3), (6, 8), (6, 10), (6, 12), (6, 13), (7, 9), (7, 11), (8, 6), (8, 10), (8, 12), (8, 13), (8, 14), (8, 15), (8, 16), (8, 24), (9, 7), (9, 11), (10, 6), (10, 8), (10, 12), (10, 13), (11, 7), (11, 9), (12, 6), (12, 8), (12, 10), (12, 13), (13, 6), (13, 8), (13, 10), (13, 12), (14, 8), (14, 15), (14, 16), (14, 24), (15, 8), (15, 14), (15, 16), (15, 19), (15, 24), (16, 8), (16, 14), (16, 15), (16, 24), (17, 18), (17, 21), (17, 23), (18, 17), (18, 21), (19, 15), (19, 20), (20, 19), (21, 17), (21, 18), (21, 22), (22, 21), (23, 17), (24, 8), (24, 14), (24, 15), (24, 16)]
# [(6, 12), (15, 24), (12, 13), (21, 22), (14, 16), (8, 12), (17, 21), (9, 11), (17, 18), (8, 15), (10, 12), (8, 24), (6, 8), (14, 15), (14, 24), (8, 14), (17, 23), (19, 20), (7, 9), (15, 16), (6, 13), (6, 10), (15, 19), (16, 24), (18, 21), (3, 5), (8, 10), (8, 16), (10, 13), (2, 3), (8, 13), (7, 11), (17, 24), (19, 24)]
# ...

# %%
greatest_corr_cols = [df.columns[df.shape[1]-1]]
for col in sptype_corr_vars:
    if df.columns[col[0]] not in greatest_corr_cols:
        greatest_corr_cols.append(df.columns[col[0]])
    else:
        pass
    
greatest_corr_cols
# Out:
# ['SpType-ELS', 'BP-G', 'BPmag', 'BP-RP', 'G-RP', 'Teff', 'Rad']

# %%
plot_rows = 0
if len(sptype_corr_vars) % 2 == 0:
    plot_rows = len(sptype_corr_vars) // 2
else:
    plot_rows = (len(sptype_corr_vars) // 2) + 1

# %% [markdown]
# A continuación, se presentan los gráficos de dispersión de los pares de variables. Se invirtieron los ejes para una mejor visualización y preferencia personal del autor de manera que se observaran los rangos de cada parámetro en comparación con cada una de las clases, además, se agregaron los parámetros de temperatura efectiva y radio (Teff y Rad), puesto que las fuentes consultadas indicaban que estos parámetros son importantes en la clasificación estelar.

# %%
fig, ax = plt.subplots(plot_rows, 2)
fig.subplots_adjust(bottom=0.1, top=2.0, right=1.3)

col_index = 0
row_idx = 0
plot_idx = 0

ticklabels = ["",'A', 'B', 'F', 'G', 'K', 'M', 'O']

    
for i in range(len(sptype_corr_vars)):
    ax[row_idx, col_index].set_xticklabels(ticklabels)
    ax[row_idx, col_index].scatter(df[df.columns[sptype_corr_vars[plot_idx][1]]], df[df.columns[sptype_corr_vars[plot_idx][0]]])
    ax[row_idx, col_index].set_title(f"{df.columns[sptype_corr_vars[plot_idx][1]]} vs {df.columns[sptype_corr_vars[plot_idx][0]]}")
    
    if col_index == 1:
        col_index = 0
        row_idx += 1
    else:
        col_index += 1
    plot_idx += 1
    
plt.show()
# Out:
# C:\Users\edwin\AppData\Local\Temp\ipykernel_18112\4005232812.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[row_idx, col_index].set_xticklabels(ticklabels)

# %% [markdown]
# A continuación, se presentan los histogramas de cada una de las variables seleccionadas por medio del criterio de la correlación.

# %%
# Se grafican los histogramas de las variables con mayor correlación
num_bins = 50
num_rows = 0
if len(greatest_corr_cols) % 2 == 0:
    num_rows = len(greatest_corr_cols) // 2
else:
    num_rows = (len(greatest_corr_cols) // 2) + 1
    
fig, axis = plt.subplots(num_rows, 2)
fig.subplots_adjust(bottom=0.1, top=2.4, right=1.5)
col_index = 0
row_idx = 0
plot_idx = 0

for i in range(len(greatest_corr_cols)):
    n, bins, patches = axis[row_idx, col_index].hist(df[greatest_corr_cols[i]], num_bins, density=True)
    axis[row_idx, col_index].set_title(f'{greatest_corr_cols[i]}')
    if col_index == 1:
        col_index = 0
        row_idx += 1
    else:
        col_index += 1
    plot_idx += 1

plt.show()

# %% [markdown]
# A partir de las gráficas obtenidas, se pueden caracterizar algunos aspectos de las variables. Por ejemplo, la variable categórica posee la misma frecuencia para cada una de las clases a excepción de las clases 1 y 6, correspondientes a las clases B y O, respectivamente. Adicionalmente, se pueden evidenciar también los valores que difieren o se alejan de la distribución, esto en alución a lo mencionado previamente con respecto a las clases B y O que son aquellas con menor cantidad de registros. A continuación se presentan los valores, menor, mayor y los de mas medidas de tendencia central de los parámetros seleccionados por el algoritmo.

# %%
from statistics import mode 

for element in greatest_corr_cols:
    print(f"\n\033[1m{element}:\033[0m Min={df[element].min()}, Max={df[element].max()}, Moda={mode(df[element])}, Media={df[element].mean()}, Mediana={df[element].median()}")
# Out:
# SpType-ELS: Min=0, Max=6, Moda=0, Media=2.6839930095195434, Mediana=3.0
#
# BP-G: Min=-1.710986, Max=5.55283, Moda=0.366591, Media=0.6295579804099474, Mediana=0.4802605
#
# BPmag: Min=3.023606, Max=21.326849, Moda=14.847903, Media=14.350160767620102, Mediana=14.681242000000001
#
# BP-RP: Min=-0.627329, Max=7.255581, Moda=0.980763, Media=1.3189717322965302, Mediana=1.1403525
#
# G-RP: Min=-0.452513, Max=2.525836, Moda=0.639071, Media=0.6894137653820249, Mediana=0.660124
#
# Teff: Min=3039.2, Max=41504.0, Moda=15005.2, Media=7194.982554042987, Mediana=5922.6
#
# Rad: Min=0.3454, Max=1105.9956, Moda=0.5376, Media=8.14179537264852, Mediana=2.0315

# %% [markdown]
# Como comprobación de las gráficas de los histogramas, se calcularon los valores mínimos, máximos, la moda, la media y la mediana de los parámetros que poseían mayor correlación con el parámetro de salida. Ahora es posible seleccionar las variables o parámetros elegidos para el estudio, a partir de la correlación entre los mismos, por lo que se creará la copia df1 del dataframe original que contendrá unicamente dichas variables.

# %%
df1 = pd.DataFrame([df[x] for x in greatest_corr_cols])
df1 = df1.T
df1 = df1.drop('SpType-ELS', axis=1)
df1.head(5)
# Out:
#        BP-G      BPmag     BP-RP      G-RP    Teff     Rad
# 0  0.041343  11.007946  0.132317  0.090974  9406.7  2.3686
# 1  0.072701  10.441856  0.236492  0.163792  9348.7  2.4642
# 2  0.173778  10.212755  0.477917  0.304139  7520.7  1.9321
# 3  0.198277  10.008457  0.537237  0.338961  7052.3  2.9735
# 4  0.034631   8.197672  0.126472  0.091842  9982.8  2.2829

# %% [markdown]
# ## Análisis de datos:
#
# ### Generación del modelo de clasificación de estrellas.
#
# Por medio de esta sección se genera el algoritmo de clasificación que permitirá predecir la clase de una nueva estrella basado en sus características.
#
# #### Separación del dataset para entrenamiento y testeo
#
# Se utiliza la librería sklearn con su módulo train_test_split para la separación del dataset con un 30% dedicado al testeo del modelo y el 70% restante para su entrenamiento.

# %%
from sklearn.model_selection import train_test_split

# %%
training_data, test_data, train_class, test_class = train_test_split(
    df1.values,
    df["SpType-ELS"].values,
    test_size=0.3
)

# %% [markdown]
# #### Implementación modelo de clasificación
#
# Se implementa un modelo de árbol de decisión que tendrá en cuenta las posibles salidas para distintos intervalos de los valores numéricos presentes en la copia del dataframe generada y distintas combinaciones de los mismos para así predecir la posible clase de una estrella no identificada. El criterio usado es 'gini' que mide la impureza de los nodos del árbol de clasificación.

# %%
from sklearn import tree

# %%
arbol_decision = tree.DecisionTreeClassifier(criterion='gini', max_depth=8)

arbol = arbol_decision.fit(training_data, train_class)

accuracy = arbol_decision.score(test_data, test_class)

df1.head(5)
# Out:
#        BP-G      BPmag     BP-RP      G-RP    Teff     Rad
# 0  0.041343  11.007946  0.132317  0.090974  9406.7  2.3686
# 1  0.072701  10.441856  0.236492  0.163792  9348.7  2.4642
# 2  0.173778  10.212755  0.477917  0.304139  7520.7  1.9321
# 3  0.198277  10.008457  0.537237  0.338961  7052.3  2.9735
# 4  0.034631   8.197672  0.126472  0.091842  9982.8  2.2829

# %%
analyzed_columns = list(df1.columns)
arbol_texto = tree.export_text(arbol, feature_names=analyzed_columns)

print(accuracy)
print(arbol_texto)
plt.figure(figsize=(60,24))
tree.plot_tree(arbol, feature_names=analyzed_columns)
plt.show()
# Out:
# 0.861607459116001
# |--- Teff <= 6948.15
# |   |--- G-RP <= 0.96
# |   |   |--- Teff <= 5390.55
# |   |   |   |--- BP-G <= 0.48
# |   |   |   |   |--- Teff <= 5209.35
# |   |   |   |   |   |--- BP-G <= 0.44
# |   |   |   |   |   |   |--- G-RP <= 0.61
# |   |   |   |   |   |   |   |--- BP-G <= 0.42
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- BP-G >  0.42
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- G-RP >  0.61
# |   |   |   |   |   |   |   |--- BP-G <= 0.42
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- BP-G >  0.42
# |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |--- BP-G >  0.44
# |   |   |   |   |   |   |--- BPmag <= 13.26
# |   |   |   |   |   |   |   |--- Teff <= 5147.50
# |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |--- Teff >  5147.50
# |   |   |   |   |   |   |   |   |--- class: 4
# ...

# %%
encoder.classes_
# Out:
# array(['A      ', 'B      ', 'F      ', 'G      ', 'K      ', 'M      ',
#        'O      '], dtype=object)

# %% [markdown]
# #### Predicción de estrellas nuevas:
#
# Posterior a la definición del modelo de clasificación, se debe poner a prueba mediante la creación de nuevos registros, la estimación de los valores de los parámetros en los intervalos observados en las gráficas de dispersión y el análisis de la distribución, y que, de esta manera el modela prediga el tipo de estrella.

# %%
# Clases esperadas: B, O, B, M, F, A
x_pred = [[1.5, 22.0, 3.0, 1.3, 10000, 100], [-0.5, 3.0, -0.6, -0.45, 40000, 100], [2.5, 19.0, -0.5, -0.25, 20000, 80], [3.0, 17.5, 4.5, 1.2, 4000, 1100],[1.0, 8.5, 2.8, 1.3, 5000, 20], [2.0, 17.5, 0.02, 0.05, 7500, 70]]
y_pred_arbol = arbol_decision.predict(x_pred)
for i in range(len(y_pred_arbol)):
    print(f"Tipo estrella estimado: {encoder.classes_[y_pred_arbol[i]]}, con índice {y_pred_arbol[i]}")
# Out:
# Tipo estrella estimado: B      , con índice 1
# Tipo estrella estimado: O      , con índice 6
# Tipo estrella estimado: O      , con índice 6
# Tipo estrella estimado: M      , con índice 5
# Tipo estrella estimado: M      , con índice 5
# Tipo estrella estimado: A      , con índice 0

# %% [markdown]
# ### Evaluación del modelo
#
# Es necesario revisar la precisión del algoritmo usado para la predicción o clasificación de las estrellas, la librería sklearn posee ya algunos parámetros de evaluación. Los modelos de métricas aplicadas son: confusion_matrix, accuracy_score

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
def metricas(clases_reales, clases_predichas):
    matriz = confusion_matrix(clases_reales, clases_predichas)
    accuracy = accuracy_score(clases_reales, clases_predichas)
    return matriz, accuracy

# %%
def visualiza_metricas(clases_reales, clases_predichas):
    matriz, accuracy = metricas(clases_reales, clases_predichas)
    plt.figure(figsize=(3,3))
    matriz = pd.DataFrame(matriz, columns=['A', 'B', 'F', 'M', 'O'])
    plt.matshow(matriz, cmap="Blues", vmin=0, vmax=10, fignum=1)
    plt.title("Reales")
    plt.ylabel("Predichas")
    plt.xticks(range(len(matriz.columns)), matriz.columns, rotation=45)
    plt.yticks(range(len(matriz.columns)), matriz.columns)
    for i in range(len(matriz.columns)):
        for j in range(len(matriz.columns)):
            plt.text(i, j + 0.14, str(matriz.iloc[i,j]), fontsize=30, ha="center", va="center")
    plt.text(5.1, 0.10, 'Exactitud: %0.2f' % accuracy, fontsize=20)
    plt.show()

# %%
# Clases esperadas: B, O, B, M, F, A
clases_reales=[1, 6, 1, 5, 2, 0]

metricas(clases_reales, y_pred_arbol)
visualiza_metricas(clases_reales, y_pred_arbol)

# %% [markdown]
# ## Resultados y discusión
#
# A pesar de que los resultados ya fueron presentados en la sección anterior, es importante discutir algunos detalles de todo el procedimiento. Se partió de una base de datos con 611689 registros de estrellas detectadas por la sonda espacial Gaia, y con 28 columnas que los caracterizaban. Tres columnas fueron eliminadas del análisis debido a que no aportaban nada al análisis o debido a una gran falta de datos como sucedió con la columna 'pscol' que tenía menos del 3% del total de registros.
#
# La realización del análisis fue inicialmente hecho a mano, sin embargo, al trabajar con 25 columnas, la graficación de parámetros se volvió tediosa, por lo que se procedió a automatizar esto por medio de bucles for dependiendo unicamente de el parámetro 'threshold', siendo este el encargado de definir las variables a evaluar de todo el conjunto de datos, simplificando además el análisis de datos y la predicción debido a la reducción del costo computacional, puesto que se redujo el dataframe a 6 parámetros.
#
# Un posible problema que se puede encontrar el lector es con respecto a los datos faltantes. Como se indicó previamente, no se eliminaron las filas con datos faltantes ya que esto implicaba la eliminación de la clase 'O' en el parámetro 'SpType-ELS', esto a su vez implica que ninguna de las estrellas de tipo O tenía registrado ese valor, por lo que tampoco era posible la imputación de datos para esa columna, y permite establecer que el registro no era preciso, o posible por parte de Gaia para este tipo de estrellas. Se recurrió a generar el análisis con la cantidad de datos que se poseían, recordando además que la cantidad de datos faltantes era menor al 30% para cada uno de los parámetros a excepción de la columna 'pscol'.
#
# <section id="gini">Finalmente, se recurrió a la implementación de un árbol de decisión como modelo de clasificación con un criterio de gini que por medio del cálculo de impureza permite definir qué tan posible es clasificar una instance erróneamente <a href="https://www.geeksforgeeks.org/gini-impurity-and-entropy-in-decision-tree-ml/">[6]</a>. Se le aplicó una profundidad de 8 capas de manera que tuviera una precisión apreciable, pero sin recurrir a un sobrecosto computacional. Posterior a la clasificación de unas estrellas con unas características arbitrarias, se procedió a evaluar el modelo, para el cual se obtuvo una exactitud del 67 %. Este resultado pudo mejorar por medio de un tratamiento más óptimo de los datos faltantes, sin embargo ya se explicaron las razones por las cuales se realizó el análisis de esta manera, o de la aplicación de más o menos capas en el árbol de decisión.</section>

# %% [markdown]
# ## Conclusiones
#
# - A través de una comprensión del conjunto de datos (conocimiento del negocio), se pudo darle un mayor sentido a los resultados obtenidos, dado que los datos poseen un transfondo científico profundo y lenguaje técnico que dificultaba la comprensión de los datos.
# - Fue posible no solo la implementación de un análisis de datos, sino de su optimización a través de estructuras de control propias del lenguaje de programación, que permitió a su vez la reducción de costo computacional al reducir el número de parámetros a analizar.
# - Se logró implementar un modelo de predicción que clasificara estrellas, que para las estrellas con parámetros arbitrarios elegidos por el autor logró un porcentaje de exactitud del 67 % como se indicó en la matriz de confusión.

# %% [markdown]
# ## Referencias
#
# - <a href="#database">[1]</a> “Kaggle Datasets.” Accessed: Nov. 12, 2023. [Online]. Available: https://www.kaggle.com/datasets/realkiller69/gaia-data-set-for-stellar-classificationdr3/data
# - <a href="#gaia">[2]</a> “Gaia’s 3D View of Our Galaxy,” Launch Pad Astronomy. Accessed: Nov. 12, 2023. [Online]. Available: https://www.youtube.com/watch?v=Ku8EGR6N1MM
# - <a href="#dr3">[3]</a> ESA, “Gaia DR3 media kit,” 2022. Accessed: Nov. 12, 2023. [Online]. Available: https://esamultimedia.esa.int/docs/science/Gaia_DR3_mediakit_final_English.pdf
# - <a href="#clasificacion">[4]</a> A. Riveiro, “La clasificación estelar,” Astrobitácora. Accessed: Nov. 12, 2023. [Online]. Available: https://www.astrobitacora.com/la-clasificacion-estelar/
# - <a href="#missingness">[5]</a> “What should be the allowed percentage of Missing Values?,” Analytics Vidhya. Accessed: Nov. 12, 2023. [Online]. Available: https://discuss.analyticsvidhya.com/t/what-should-be-the-allowed-percentage-of-missing-values/2456
# - <a href="#gini">[6]</a> “ML | Gini Impurity and Entropy in Decision Tree,” Geeks for Geeks. Accessed: Nov. 12, 2023. [Online]. Available: https://www.geeksforgeeks.org/gini-impurity-and-entropy-in-decision-tree-ml/
